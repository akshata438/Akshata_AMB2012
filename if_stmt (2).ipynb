# %%
r=int(input("enter a radius of a circle"))
o=int(input("choose 1 if you want perimeter or else choose 2 for area"))
p=3.14*2*r
a=3.14*r*r
if(o==1):
  print("perimeter of circle is",p)
elif(o==2):
  print("area of a circle isa",a)
else:
  print("error")
# Out:
# enter a radius of a circle5
# choose 1 if you want perimeter or else choose 2 for area1
# perimeter of circle is 31.400000000000002

# %%
n=35
if(n%5==0 and n%7==0):
  print(" n is divisible by both 7&5")
else:
  print("not divisible by both")
# Out:
#  n is divisible by both 7&5

# %%
for i in range(1,3,1):
  print(i)
# Out:
# 1
# 2

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
if(a>b):
  print("{}is greater between{}and{}".format(a,a,b))
elif(b>a):
  print("{}is greater betweeen{}and {}".format (b,a,b))
else:
  print(" a and b are equal")
# Out:
# enter a number52
# enter a number65
# 65is greater betweeen52and 65

# %%
list1=[1,8,9,'hi',0]
list1.append('hi')
print (list1)
print(list1.count(0))
# Out:
# [1, 8, 9, 'hi', 0, 'hi']
# 1

# %%
list1.insert(8,8)
list1
# Out:
# [1, 8, 9, 'hi', 0, 'hi', 8]

# %%
list1.reverse()
print(list1)
# Out:
# [8, 'hi', 0, 'hi', 9, 8, 1]

# %%
print(list1*
      4561)
# Out:
# [8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1, 8, 'hi', 0, 'hi', 9, 8, 1
# ...
