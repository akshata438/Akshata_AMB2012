# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
file=open("gkvk.txt","w")
file.write("hiiiiiiii.....😍")
file.close()

# %%
file=open("gkvk.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hiiiiiiii.....😍

# %%
file=open("gkvk.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hiiiiiiii.....😍

# %%
file=open("gkvk.txt","w")
file.write("hiiiiiiii.....😍 .........")

# %%
file=open("gkvk.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hiiiiiiii.....😍

# %%
file=open("gkvk.txt","a")
file.write("hiiiiiiii.....😍 .........")
file.close()

# %%
file=open("gkvk.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# hiiiiiiii.....😍hiiiiiiii.....😍 .........hiiiiiiii.....😍 .........

# %%
#exception handeling
try:
  file=open("xyz.txt","r")
  content=file.read()
  print(content)
  file.close()
except:
  print(" no such file")
# Out:
#  no such file

# %%
try:
  a=10
  b=32
  c=a+d
  print(c)
except:
  print("some issue")
# Out:
# some issue

# %%
def exp(a,b):
 c=a/b
 print(c)
a=5
b=2
exp(a,b)
# Out:
# 2.5

# %%
def exp(a,b):
 c=a/b
 print(c)
a=5
b=0
exp(a,b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-178983050.py in <cell line: 0>()
#       4 a=5
#       5 b=0
# ----> 6 exp(a,b)
#
# /tmp/ipython-input-178983050.py in exp(a, b)
#       1 def exp(a,b):
# ----> 2  c=a/b
#       3  print(c)
#       4 a=5
#       5 b=0
#
# ZeroDivisionError: division by zero

# %%
def exp(a,b):
  try:
    c=a/f
  except ZeroDivisionError:
    print("divided by zero")
  except NameError:
    print("variable not defined")
  except:
    print("some error")
  else:
    print("executed without error")
    print(c)
  finally:
    print("end program")
a=5
b=0
exp(a,b)
# Out:
# variable not defined
# end program
