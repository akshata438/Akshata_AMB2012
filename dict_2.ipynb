# %%
dict={"rice":120,"wheat":85,"maize":60}
print(dict)
# Out:
# {'rice': 120, 'wheat': 85, 'maize': 60}

# %%
print("total no of crops cultivated by a farmer",len(dict))
# Out:
# total no of crops cultivated by a farmer 3

# %%
keylist=list(dict.keys())
vallist=list(dict.values())
print(keylist)
print(vallist)
print(("yield of",keylist[1],'is',vallist[1]))
# Out:
# ['rice', 'wheat', 'maize']
# [120, 85, 60]
# ('yield of', 'wheat', 'is', 85)

# %%
dict={"rice":120,"wheat":85,"maize":60}

# %%
print("yield of wheat is",dict.get("wheat"))
# Out:
# yield of wheat is 85

# %%
dict["pulses"]=45
print(dict)
# Out:
# {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
dict["rice"]=130
print(dict)
# Out:
# {'rice': 130, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
print(dict.keys())
print(dict.values())
# Out:
# dict_keys(['rice', 'wheat', 'maize', 'pulses'])
# dict_values([130, 85, 60, 45])

# %%
print("sugarcane is there in crop list:","sugarcane"in dict.keys())
# Out:
# sugarcane is there in crop list: False

# %%
dict["wheat"]+=10
print(dict)
# Out:
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

# %%
print("sum of yield is ",sum(dict.values()))
# Out:
# sum of yield is  330

# %%
dict={"rice":120,"wheat":85,"maize":60}
for k,v in dict.items():
 print(k,":",v)
# Out:
# rice : 120
# wheat : 85
# maize : 60

# %%
keylist=list(dict.keys())
vallist=list(dict.values())
mdict={}
for i in range(len(keylist)):
    mdict[keylist[i]]=vallist[i]
print(mdict)
# Out:
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

# %%
dict2=dict
print(dict2)
# Out:
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

# %%
dict.clear()
print(dict)
# Out:
# {}

# %%
print("yield of jowar",dict2.get("jowar"))
# Out:
# yield of jowar None

# %%
if ("jowar" in dict.keys()):
  print("jowar is present")
else:
   print("jower is not there")
# Out:
# jower is not there

# %%
print(dict.get("jowar"))
# Out:
# None

# %%
del dict["maize"]
print(dict)
# Out:
# {'rice': 120, 'wheat': 85}

# %%
del dict["maize"]
print(dict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2379853884.py in <cell line: 0>()
# ----> 1 del dict["maize"]
#       2 print(dict)
#
# KeyError: 'maize'

# %%
dict.pop("wheat")
print(dict)
# Out:
# {'rice': 120}

# %%
dict.clear
# Out:
# <function dict.clear>

# %%
print(dict)
# Out:
# {'rice': 120}
