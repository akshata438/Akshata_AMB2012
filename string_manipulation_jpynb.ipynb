# %%
fruit="banana"
letter=fruit[1]
print(letter)
# Out:
# a

# %%
q="queen  "
print(q[0:4])
# Out:
# quee

# %%
print(q[4:5])
# Out:
# n

# %%
print(q[-1:-3])

# %%
print(q[-3:-1])
# Out:
# ee

# %%
print(len(q))
# Out:
# 5

# %%
j="joker  "

# %%
len(j)
# Out:
# 7

# %%
str1="hello"
str2="world"
print(str1+" "+str2)
# Out:
# hello world

# %%
b=str1+"there"
print(b)
# Out:
# hellothere

# %%
s="hello""welcomee"
print(s)
# Out:
# hellowelcomee

# %%
s="hello"
"welcome"
print(s)
# Out:
# hello

# %%
s=("hello\n""world")
print(s)
# Out:
# hello
# world

# %%
s=("hello"
... "world")
print(s)
# Out:
# helloworld

# %%
print(s.count("l"))
# Out:
# 3

# %%
c=0
for i in s:
  if i=="l":
   c=c+1
print(c)
# Out:
# 3

# %%
fruit="banana"
print("n" in fruit)
# Out:
# True

# %%
"nan"in fruit
# Out:
# True

# %%
"m " in fruit
# Out:
# False

# %%
"n "in fruit
# Out:
# False

# %%
if "n" in fruit:
  print("found it")
# Out:
# found it

# %%
fruit.count("nan")
# Out:
# 1

# %%
fruit.find("b")
# Out:
# 0

# %%
fruit.find("n")
# Out:
# 2

# %%
fruit.find("nan")
# Out:
# 2

# %%
fruit.find("naa")
# Out:
# -1

# %%
fruit.upper()
# Out:
# 'BANANA'

# %%
fruit.lower()
# Out:
# 'banana'

# %%
fruit.capitalize()
# Out:
# 'Banana'

# %%
f="pine apple"
f.capitalize()
# Out:
# 'Pine apple'

# %%
f="pine Apple"
f.capitalize()
# Out:
# 'Pine apple'

# %%
f="pine apple.EATING"
f.capitalize()
# Out:
# 'Pine apple.eating'

# %%
g="hello morning"
s=g.replace("hello","gud")
print(s)
print(g)
# Out:
# gud morning
# hello morning

# %%
a="    good morning      "
s=a.strip()
print(s)
# Out:
# good morning

# %%
a="    good morning     n "
q=a.lstrip()
print(q)
# Out:
# good morning     n

# %%
a="    good morning      "
s=a.rstrip()
print(s)
# Out:
#     good morning

# %%
s="hello world"
m=s.split()
print(m)
# Out:
# ['hello', 'world']

# %%
s="hello world"
m=s.split("  ")
print(m)
# Out:
# ['hello world']

# %%
s="hello world"
m=s.split("r")
print(m)
# Out:
# ['hello wo', 'ld']

# %%
s="hello world"
m=s.split("j")
print(m)
# Out:
# ['hello world']

# %%
str1="gyufgvf"
str2=".".join(str1)
print(str2)
# Out:
# g.y.u.f.g.v.f

# %%
s1="khushi"
rev=s1[::-1]
print(rev)
# Out:
# ihsuhk

# %%
s=" ".join(reversed(s1))
print(s)
# Out:
# i h s u h k

# %%
c=0
for i in s:
  if i=="l":
   c=c+1
print(c)

# %%
crop_name="Ground nut"
print(crop_name[0])
print(crop_name[-1])
print(crop_name[5])
print(crop_name[:5])
# Out:
# G
# t
# d
# Groun

# %%
print("green gram".title())
# Out:
# Green Gram

# %%
c="  rice "
print(c.strip())
print(c.lstrip())
# Out:
# rice
# rice

# %%
print("***wheat/*/*".lstrip("*"))
# Out:
# wheat/*/*

# %%
text="organic rice and rice"
print(text.find("rice"))
print("rice" in text)
# Out:
# 8
# True

# %%
print("rice".isalpha())
print("rice123".isalpha())
print("rice".isdigit())
print("12h".isalnum())
print(" ".isspace())
# Out:
# True
# False
# False
# True
# True

# %%
c="rice crop"
a=c.replace("rice","mango")
print(a)
# Out:
# mango crop

# %%
r="rice,234,ttt,5656"
f=r.split(",")
print(f)
j=",".join(f)
print(j)
# Out:
# ['rice', '234', 'ttt', '5656']
# rice,234,ttt,5656

# %%
c="rice"
y=1200
print(f"crop:{c},yield:{y}")
print("crop:{},yield:{}".format(c,y))
# Out:
# crop:rice,yield:1200
# crop:rice,yield:1200

# %%
print("farmers crop record")
print("line1 \nline2")
print(sorted("wheaT"))
# Out:
# farmers crop record
# line1
# line2
# ['T', 'a', 'e', 'h', 'w']

# %%
c="crp_rice_2026"
print(c.startswith("crp"))
print(c.endswith("2020"))
# Out:
# True
# False

# %%
codes=[
    "CRP_RICE_2026"
    "CRP_WHEAT_2026"
    "CRP_SUGARCANE_2024"
]
filtered=[]
for c in codes:
  if c.startswith("CRP"):
   filtered.append(c)
  print(filtered)
# Out:
# ['CRP_RICE_2026CRP_WHEAT_2026CRP_SUGARCANE_2024']

# %%
codes=[
    "CRP_RICE_2026"
    "CRP_WHEAT_2026"
    "CRP_SUGARCANE_2024"]
CLEAN_CODES=[]
for c in codes:
      if c.startswith("CRP"):
        CLEAN_CODES.append(codes[:4])
        print(CLEAN_CODES)
# Out:
# [['CRP_RICE_2026CRP_WHEAT_2026CRP_SUGARCANE_2024']]

# %%
raw_record="   rice,1200,blacksoil**"
clean_record=raw_record.strip()
print(clean_record)
# Out:
# rice,1200,blacksoil**

# %%
a="today is 20-Jan-2026 monday"
b=v=c=d=o=0
for i in a:
  if i==" ":
    b=b+1
  elif i in "aeiou":
    v=v+1
  elif i.isalpha():
    c=c+1
  elif i.isdigit():
    d=d+1
  else:
    o=o+1
print(b)
print(v)
print(c)
print(d)
print(o)
print(len(a))
# Out:
# 3
# 6
# 10
# 6
# 2
# 27
