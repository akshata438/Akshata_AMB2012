# %%
num1 = 10
num2 = 20

is_greater = num1 > num2
is_equal = num1 == num2

print(f"{num1} > {num2} is {is_greater}")
print(f"{num1} == {num2} is {is_equal}")
# Out:
# 10 > 20 is False
# 10 == 20 is False

# %%
print(f"bool(0) is {bool(0)}")
print(f"bool(5) is {bool(5)}")
print(f"bool('') is {bool('')}")
print(f"bool('hello') is {bool('hello')}")
print(f"bool([]) is {bool([])}")
print(f"bool([1, 2]) is {bool([1, 2])}")
# Out:
# bool(0) is False
# bool(5) is True
# bool('') is False
# bool('hello') is True
# bool([]) is False
# bool([1, 2]) is True
